# %% [markdown]
# # Running back prediction model
#
# ## I will ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# Here we can see the pattern that running backs do not tend to have long careers.

# %%
fantasy_stats = pd.read_csv("data/fantasy_data.csv")
rbs = fantasy_stats[fantasy_stats["Pos"] == "RB"].copy()
career_lengths = rbs.groupby("Player")["Year"].nunique()
career_lengths.hist(bins=15)
# Out:
# <Axes: >

# %%
avg_by_age = rbs.groupby("Age")["Rush_Yds"].mean()
avg_by_age.plot(kind="bar", title="Avg rushing yards by age")
# Out:
# <Axes: title={'center': 'Avg rushing yards by age'}, xlabel='Age'>

# %%
starters_flag = rbs.groupby("Player")["games_started_pct"].max().reset_index()

starters_flag = starters_flag[(rbs.groupby("Player")["G"].max().reset_index()["G"] > 12)]

starters = rbs[rbs["Player"].isin(starters_flag["Player"])]

# %%
# Fantasy scoring
starters = starters.copy()

starters.loc[:, "fantasy_points"] = (
    starters["Rush_Yds"] / 10
    + starters["Rec_Yds"] / 10
    + starters["Rush_TD"] * 6
    + starters["Rec_TD"] * 6
    - starters["FmbLost"] * 2
)

# %%
plt.hist(starters["fantasy_points"], bins=50, edgecolor="black")
plt.xlabel("Fantasy Points (per season)")
plt.ylabel("Number of RB seasons")
plt.title("Distribution of Fantasy Points for Starter RBs")
plt.show()

# %%
career_points = starters.groupby(["Player", "Year"])["fantasy_points"].sum().reset_index()

# Example: Look at one player’s trajectory
example_rb = career_points[career_points["Player"] == "Adrian Peterson"]
plt.plot(example_rb["Year"], example_rb["fantasy_points"], marker="o")
plt.title("Adrian Peterson Fantasy Points by Year")
plt.xlabel("Year")
plt.ylabel("Fantasy Points")
plt.show()

# %%
# Add a career year index per player
starters["career_year"] = starters.groupby("Player").cumcount() + 1

avg_by_career_year = starters.groupby("career_year")["fantasy_points"].mean()

avg_by_career_year.plot(marker="o")
plt.title("Average RB Fantasy Points by Career Year")
plt.xlabel("Career Year")
plt.ylabel("Fantasy Points")
plt.show()

# %%
sns.boxplot(x="career_year", y="fantasy_points", data=starters)
plt.title("Fantasy Points Distribution by Career Year")
plt.show()

# %% [markdown]
# # Engineering Features

# %%
def preprocess_starters(starters):
    starters = starters.sort_values(["Player", "Year"]).reset_index(drop=True)

    starters["fantasy_prev"] = starters.groupby("Player")["fantasy_points"].shift(1)
    starters["rush_att_prev"] = starters.groupby("Player")["Rush_Att"].shift(1)
    starters["rec_prev"] = starters.groupby("Player")["Rec_Rec"].shift(1)
    starters["touches_prev"] = starters["rush_att_prev"] + starters["rec_prev"]

    starters["fantasy_avg_2"] = starters.groupby("Player")["fantasy_points"].transform(
        lambda x: x.shift(1).rolling(2).mean())
    starters["fantasy_avg_3"] = starters.groupby("Player")["fantasy_points"].transform(
        lambda x: x.shift(1).rolling(3).mean())

    starters["fantasy_diff_1"] = starters["fantasy_prev"] - starters.groupby("Player")["fantasy_points"].shift(2)

    starters["age"] = starters["Age"]
    starters["years_in_league"] = starters.groupby("Player").cumcount() + 1

    starters["games_prev"] = starters.groupby("Player")["G"].shift(1)
    starters["max_games"] = starters["Year"].apply(lambda x: 17 if x >= 2021 else 16)
    starters["missed_games_prev"] = starters["max_games"] - starters.groupby("Player")["G"].shift(1)

    #  DO NOT filter non-rookies here
    return starters.copy()

# %%
def make_yearly_comparison(starters_model, prediction_year, features, espn_path_template="data/ESPN{}.csv"):
    """
    Trains a linear regression model on all years < prediction_year,
    predicts fantasy points for prediction_year, compares to ESPN projections,
    and returns a styled table with ranking comparison and average error.
    """
    from sklearn.linear_model import LinearRegression
    import pandas as pd
    import numpy as np

    # -------------------------------
    # 1. Train/test split
    # -------------------------------
    data = starters_model.dropna(subset=features + ["fantasy_points"])
    train = data[data["Year"] < prediction_year]
    test = data[data["Year"] == prediction_year]

    X_train, y_train = train[features], train["fantasy_points"]
    X_test, y_test = test[features], test["fantasy_points"]

    # -------------------------------
    # 2. Fit Linear Regression model
    # -------------------------------
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    test = test.copy()
    test["predicted_fp"] = lr.predict(X_test)

    # Rank by predicted fantasy points
    test["predicted_rank"] = test["predicted_fp"].rank(ascending=False, method="min").astype(int)

    # Exclude rookies for actual ranks
    test_non_rookies = test[test["years_in_league"] > 1].copy()
    test_non_rookies["actual_rank"] = test_non_rookies["fantasy_points"].rank(ascending=False, method="min").astype(int)

    # -------------------------------
    # 3. Merge ESPN projections
    # -------------------------------
    espn = pd.read_csv(espn_path_template.format(prediction_year))
    espn["Player"] = espn["Player"].str.strip()
    test_non_rookies["Player"] = test_non_rookies["Player"].str.strip()
    test_non_rookies = test_non_rookies.merge(espn[["Player","Pred_Rank"]], on="Player", how="left")
    test_non_rookies.rename(columns={"Pred_Rank": "espn_rank"}, inplace=True)

    # Fill missing ESPN ranks with 1 more than max (assumes 85 ranked RBs)
    test_non_rookies["espn_rank_filled"] = test_non_rookies["espn_rank"].fillna(86)

    # -------------------------------
    # 4. Compute errors
    # -------------------------------
    test_non_rookies["your_error"] = (test_non_rookies["predicted_rank"] - test_non_rookies["actual_rank"]).abs()
    test_non_rookies["espn_error"] = (test_non_rookies["espn_rank_filled"] - test_non_rookies["actual_rank"]).abs()

    # Restrict to top 20 actual RBs
    top_actual = test_non_rookies[test_non_rookies["actual_rank"] <= 20].copy()

    # -------------------------------
    # 5. Build table
    # -------------------------------
    table = top_actual[[
        "Player", "predicted_rank", "espn_rank", "actual_rank", "your_error", "espn_error"
    ]].rename(columns={
        "predicted_rank": "Your Rank",
        "espn_rank": "ESPN Rank",
        "actual_rank": "Actual Rank",
        "your_error": "Your Error",
        "espn_error": "ESPN Error"
    }).sort_values("Actual Rank").reset_index(drop=True)

    # Convert ESPN Rank to integers where possible, otherwise "unranked"
    table["ESPN Rank"] = table["ESPN Rank"].fillna("unranked")
    table.loc[table["ESPN Rank"] != "unranked", "ESPN Rank"] = table.loc[table["ESPN Rank"] != "unranked", "ESPN Rank"].astype(int)

    # Cast errors to int for players
    table.loc[table["Player"] != "Average Error", ["Your Error", "ESPN Error"]] = (
        table.loc[table["Player"] != "Average Error", ["Your Error", "ESPN Error"]].astype(int)
    )

    # Compute average errors
    avg_your_error = table.loc[table["Player"] != "Average Error", "Your Error"].mean()
    avg_espn_error = table.loc[table["Player"] != "Average Error", "ESPN Error"].mean()

    summary_row = pd.DataFrame([{
        "Player": "Average Error",
        "Your Rank": "",
        "ESPN Rank": "",
        "Actual Rank": "",
        "Your Error": round(avg_your_error, 2),
        "ESPN Error": round(avg_espn_error, 2)
    }])

    table_with_summary = pd.concat([table, summary_row], ignore_index=True)

    # -------------------------------
    # 6. Styling function
    # -------------------------------
    def highlight_winner(row):
        colors = [''] * len(row)
        if row["Player"] == "Average Error":
            if row["Your Error"] < row["ESPN Error"]:
                colors[4] = 'background-color: lightgreen'
                colors[5] = 'background-color: lightcoral'
            elif row["Your Error"] > row["ESPN Error"]:
                colors[4] = 'background-color: lightcoral'
                colors[5] = 'background-color: lightgreen'
            else:
                colors[4] = colors[5] = 'background-color: khaki'
        else:
            if row["ESPN Rank"] == "unranked":
                colors[1] = 'background-color: lightgreen'
                colors[2] = 'background-color: lightcoral'
                colors[4] = 'background-color: lightgreen'
                colors[5] = 'background-color: lightcoral'
            elif row["Your Error"] < row["ESPN Error"]:
                colors[1] = 'background-color: lightgreen'
                colors[2] = 'background-color: lightcoral'
                colors[4] = 'background-color: lightgreen'
                colors[5] = 'background-color: lightcoral'
            elif row["Your Error"] > row["ESPN Error"]:
                colors[1] = 'background-color: lightcoral'
                colors[2] = 'background-color: lightgreen'
                colors[4] = 'background-color: lightcoral'
                colors[5] = 'background-color: lightgreen'
            else:
                colors[1] = colors[2] = colors[4] = colors[5] = 'background-color: khaki'
        return colors

    # -------------------------------
    # 7. Apply styling and return
    # -------------------------------
    return table_with_summary.style.apply(highlight_winner, axis=1).hide(axis='index')

# %%
def predict_future_year(starters_model, prediction_year, features, top_n=20):
    """
    Train on all years < prediction_year, predict fantasy points for players
    from the last available season (prediction_year - 1).
    """
    data = starters_model.dropna(subset=features + ["fantasy_points"])

    # Train on everything up to year before prediction_year
    train = data[data["Year"] < prediction_year]
    last_season = data[data["Year"] == prediction_year - 1]

    X_train = train[features]
    y_train = train["fantasy_points"]

    X_test = last_season[features]

    # Train model
    lr = LinearRegression()
    lr.fit(X_train, y_train)

    # Predict for last season’s players as if it were prediction_year
    y_pred = lr.predict(X_test)

    test = last_season.copy()
    test["predicted_fp"] = y_pred
    test["Predicted Rank"] = test["predicted_fp"].rank(ascending=False, method="min").astype(int)

    # Keep only player + rank
    top_predicted = (
        test.sort_values("Predicted Rank")
            .head(top_n)[["Player", "Predicted Rank"]]
            .reset_index(drop=True)
    )
    return top_predicted.style.hide(axis="index")

# %%
# Preprocess data
starters_model = preprocess_starters(starters)

lag_features = ["fantasy_prev", "rush_att_prev", "rec_prev", "touches_prev",
                "fantasy_avg_2", "fantasy_avg_3", "fantasy_diff_1", "games_prev", "missed_games_prev"]

starters_model[lag_features] = starters_model[lag_features].fillna(0)

features = ["fantasy_prev", "rush_att_prev", "rec_prev", "touches_prev", "fantasy_avg_2",
            "fantasy_avg_3", "fantasy_diff_1", "age", "years_in_league", "games_prev", "missed_games_prev"]

table_2023 = make_yearly_comparison(starters_model, 2023, features)

table_2023  # displays the styled comparison for 2023
# Out:
# <style type="text/css">
# #T_cabe0_row0_col1, #T_cabe0_row0_col4, #T_cabe0_row1_col1, #T_cabe0_row1_col4, #T_cabe0_row2_col1, #T_cabe0_row2_col4, #T_cabe0_row3_col1, #T_cabe0_row3_col4, #T_cabe0_row4_col2, #T_cabe0_row4_col5, #T_cabe0_row5_col1, #T_cabe0_row5_col4, #T_cabe0_row6_col2, #T_cabe0_row6_col5, #T_cabe0_row7_col1, #T_cabe0_row7_col4, #T_cabe0_row8_col2, #T_cabe0_row8_col5, #T_cabe0_row9_col1, #T_cabe0_row9_col4, #T_cabe0_row10_col2, #T_cabe0_row10_col5, #T_cabe0_row11_col2, #T_cabe0_row11_col5, #T_cabe0_row12_col1, #T_cabe0_row12_col4, #T_cabe0_row13_col1, #T_cabe0_row13_col4, #T_cabe0_row14_col1, #T_cabe0_row14_col4, #T_cabe0_row15_col1, #T_cabe0_row15_col4, #T_cabe0_row16_col2, #T_cabe0_row16_col5, #T_cabe0_row17_col1, #T_cabe0_row17_col4, #T_cabe0_row18_col2, #T_cabe0_row18_col5, #T_cabe0_row19_col2, #T_cabe0_row19_col5, #T_cabe0_row20_col4 {
#   background-color: lightcoral;
# }
# #T_cabe0_row0_col2, #T_cabe0_row0_col5, #T_cabe0_row1_col2, #T_cabe0_row1_col5, #T_cabe0_row2_col2, #T_cabe0_row2_col5, #T_cabe0_row3_col2, #T_cabe0_row3_col5, #T_cabe0_row4_col1, #T_cabe0_row4_col4, #T_cabe0_row5_col2, #T_cabe0_row5_col5, #T_cabe0_row6_col1, #T_cabe0_row6_col4, #T_cabe0_row7_col2, #T_cabe0_row7_col5, #T_cabe0_row8_col1, #T_cabe0_row8_col4, #T_cabe0_row9_col2, #T_cabe0_row9_col5, #T_cabe0_row10_col1, #T_cabe0_row10_col4, #T_cabe0_row11_col1, #T_cabe0_row11_col4, #T_cabe0_row12_col2, #T_cabe0_row12_col5, #T_cabe0_row13_col2, #T_cabe0_row13_col5, #T_cabe0_row14_col2, #T_cabe0_row14_col5, #T_cabe0_row15_col2, #T_cabe0_row15_col5, #T_cabe0_row16_col1, #T_cabe0_row16_col4, #T_cabe0_row17_col2, #T_cabe0_row17_col5, #T_cabe0_row18_col1, #T_cabe0_row18_col4, #T_cabe0_row19_col1, #T_cabe0_row19_col4, #T_cabe0_row20_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cabe0">
#   <thead>
#     <tr>
#       <th id="T_cabe0_level0_col0" class="col_heading level0 col0" >Player</th>
#       <th id="T_cabe0_level0_col1" class="col_heading level0 col1" >Your Rank</th>
#       <th id="T_cabe0_level0_col2" class="col_heading level0 col2" >ESPN Rank</th>
#       <th id="T_cabe0_level0_col3" class="col_heading level0 col3" >Actual Rank</th>
#       <th id="T_cabe0_level0_col4" class="col_heading level0 col4" >Your Error</th>
#       <th id="T_cabe0_level0_col5" class="col_heading level0 col5" >ESPN Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cabe0_row0_col0" class="data row0 col0" >Christian McCaffrey</td>
#       <td id="T_cabe0_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_cabe0_row0_col2" class="data row0 col2" >3.000000</td>
#       <td id="T_cabe0_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_cabe0_row0_col4" class="data row0 col4" >4.000000</td>
#       <td id="T_cabe0_row0_col5" class="data row0 col5" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row1_col0" class="data row1 col0" >Raheem Mostert</td>
#       <td id="T_cabe0_row1_col1" class="data row1 col1" >54</td>
#       <td id="T_cabe0_row1_col2" class="data row1 col2" >35.000000</td>
#       <td id="T_cabe0_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_cabe0_row1_col4" class="data row1 col4" >52.000000</td>
#       <td id="T_cabe0_row1_col5" class="data row1 col5" >33.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row2_col0" class="data row2 col0" >Kyren Williams</td>
#       <td id="T_cabe0_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_cabe0_row2_col2" class="data row2 col2" >49.000000</td>
#       <td id="T_cabe0_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_cabe0_row2_col4" class="data row2 col4" >69.000000</td>
#       <td id="T_cabe0_row2_col5" class="data row2 col5" >46.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row3_col0" class="data row3 col0" >Travis Etienne</td>
#       <td id="T_cabe0_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_cabe0_row3_col2" class="data row3 col2" >8.000000</td>
#       <td id="T_cabe0_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_cabe0_row3_col4" class="data row3 col4" >12.000000</td>
#       <td id="T_cabe0_row3_col5" class="data row3 col5" >4.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row4_col0" class="data row4 col0" >Joe Mixon</td>
#       <td id="T_cabe0_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_cabe0_row4_col2" class="data row4 col2" >9.000000</td>
#       <td id="T_cabe0_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_cabe0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_cabe0_row4_col5" class="data row4 col5" >4.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row5_col0" class="data row5 col0" >Breece Hall</td>
#       <td id="T_cabe0_row5_col1" class="data row5 col1" >29</td>
#       <td id="T_cabe0_row5_col2" class="data row5 col2" >16.000000</td>
#       <td id="T_cabe0_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_cabe0_row5_col4" class="data row5 col4" >23.000000</td>
#       <td id="T_cabe0_row5_col5" class="data row5 col5" >10.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row6_col0" class="data row6 col0" >Derrick Henry</td>
#       <td id="T_cabe0_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_cabe0_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_cabe0_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_cabe0_row6_col4" class="data row6 col4" >4.000000</td>
#       <td id="T_cabe0_row6_col5" class="data row6 col5" >6.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row7_col0" class="data row7 col0" >Rachaad White</td>
#       <td id="T_cabe0_row7_col1" class="data row7 col1" >42</td>
#       <td id="T_cabe0_row7_col2" class="data row7 col2" >17.000000</td>
#       <td id="T_cabe0_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_cabe0_row7_col4" class="data row7 col4" >34.000000</td>
#       <td id="T_cabe0_row7_col5" class="data row7 col5" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row8_col0" class="data row8 col0" >David Montgomery</td>
#       <td id="T_cabe0_row8_col1" class="data row8 col1" >25</td>
#       <td id="T_cabe0_row8_col2" class="data row8 col2" >26.000000</td>
#       <td id="T_cabe0_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_cabe0_row8_col4" class="data row8 col4" >16.000000</td>
#       <td id="T_cabe0_row8_col5" class="data row8 col5" >17.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row9_col0" class="data row9 col0" >James Cook</td>
#       <td id="T_cabe0_row9_col1" class="data row9 col1" >47</td>
#       <td id="T_cabe0_row9_col2" class="data row9 col2" >22.000000</td>
#       <td id="T_cabe0_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_cabe0_row9_col4" class="data row9 col4" >37.000000</td>
#       <td id="T_cabe0_row9_col5" class="data row9 col5" >12.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row10_col0" class="data row10 col0" >Saquon Barkley</td>
#       <td id="T_cabe0_row10_col1" class="data row10 col1" >8</td>
#       <td id="T_cabe0_row10_col2" class="data row10 col2" >5.000000</td>
#       <td id="T_cabe0_row10_col3" class="data row10 col3" >11</td>
#       <td id="T_cabe0_row10_col4" class="data row10 col4" >3.000000</td>
#       <td id="T_cabe0_row10_col5" class="data row10 col5" >6.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row11_col0" class="data row11 col0" >James Conner</td>
#       <td id="T_cabe0_row11_col1" class="data row11 col1" >15</td>
#       <td id="T_cabe0_row11_col2" class="data row11 col2" >20.000000</td>
#       <td id="T_cabe0_row11_col3" class="data row11 col3" >12</td>
#       <td id="T_cabe0_row11_col4" class="data row11 col4" >3.000000</td>
#       <td id="T_cabe0_row11_col5" class="data row11 col5" >8.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cabe0_row12_col0" class="data row12 col0" >Gus Edwards</td>
#       <td id="T_cabe0_row12_col1" class="data row12 col1" >56</td>
#       <td id="T_cabe0_row12_col2" class="data row12 col2" >44.000000</td>
#       <td id="T_cabe0_row12_col3" class="data row12 col3" >13</td>
#       <td id="T_cabe0_row12_col4" class="data row12 col4" >43.0

# %%
table_2024 = make_yearly_comparison(starters_model, 2024, features)
table_2024
# Out:
# <style type="text/css">
# #T_774b7_row0_col1, #T_774b7_row0_col4, #T_774b7_row1_col2, #T_774b7_row1_col5, #T_774b7_row2_col1, #T_774b7_row2_col4, #T_774b7_row3_col1, #T_774b7_row3_col4, #T_774b7_row4_col1, #T_774b7_row4_col4, #T_774b7_row5_col2, #T_774b7_row5_col5, #T_774b7_row6_col2, #T_774b7_row6_col5, #T_774b7_row7_col2, #T_774b7_row7_col5, #T_774b7_row8_col1, #T_774b7_row8_col4, #T_774b7_row9_col1, #T_774b7_row9_col4, #T_774b7_row10_col2, #T_774b7_row10_col5, #T_774b7_row11_col2, #T_774b7_row11_col5, #T_774b7_row12_col2, #T_774b7_row12_col5, #T_774b7_row13_col1, #T_774b7_row13_col4, #T_774b7_row14_col2, #T_774b7_row14_col5, #T_774b7_row15_col1, #T_774b7_row15_col4, #T_774b7_row16_col1, #T_774b7_row16_col4, #T_774b7_row17_col2, #T_774b7_row17_col5, #T_774b7_row19_col2, #T_774b7_row19_col5, #T_774b7_row20_col5 {
#   background-color: lightgreen;
# }
# #T_774b7_row0_col2, #T_774b7_row0_col5, #T_774b7_row1_col1, #T_774b7_row1_col4, #T_774b7_row2_col2, #T_774b7_row2_col5, #T_774b7_row3_col2, #T_774b7_row3_col5, #T_774b7_row4_col2, #T_774b7_row4_col5, #T_774b7_row5_col1, #T_774b7_row5_col4, #T_774b7_row6_col1, #T_774b7_row6_col4, #T_774b7_row7_col1, #T_774b7_row7_col4, #T_774b7_row8_col2, #T_774b7_row8_col5, #T_774b7_row9_col2, #T_774b7_row9_col5, #T_774b7_row10_col1, #T_774b7_row10_col4, #T_774b7_row11_col1, #T_774b7_row11_col4, #T_774b7_row12_col1, #T_774b7_row12_col4, #T_774b7_row13_col2, #T_774b7_row13_col5, #T_774b7_row14_col1, #T_774b7_row14_col4, #T_774b7_row15_col2, #T_774b7_row15_col5, #T_774b7_row16_col2, #T_774b7_row16_col5, #T_774b7_row17_col1, #T_774b7_row17_col4, #T_774b7_row19_col1, #T_774b7_row19_col4, #T_774b7_row20_col4 {
#   background-color: lightcoral;
# }
# #T_774b7_row18_col1, #T_774b7_row18_col2, #T_774b7_row18_col4, #T_774b7_row18_col5 {
#   background-color: khaki;
# }
# </style>
# <table id="T_774b7">
#   <thead>
#     <tr>
#       <th id="T_774b7_level0_col0" class="col_heading level0 col0" >Player</th>
#       <th id="T_774b7_level0_col1" class="col_heading level0 col1" >Your Rank</th>
#       <th id="T_774b7_level0_col2" class="col_heading level0 col2" >ESPN Rank</th>
#       <th id="T_774b7_level0_col3" class="col_heading level0 col3" >Actual Rank</th>
#       <th id="T_774b7_level0_col4" class="col_heading level0 col4" >Your Error</th>
#       <th id="T_774b7_level0_col5" class="col_heading level0 col5" >ESPN Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_774b7_row0_col0" class="data row0 col0" >Derrick Henry</td>
#       <td id="T_774b7_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_774b7_row0_col2" class="data row0 col2" >7.000000</td>
#       <td id="T_774b7_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_774b7_row0_col4" class="data row0 col4" >3.000000</td>
#       <td id="T_774b7_row0_col5" class="data row0 col5" >6.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row1_col0" class="data row1 col0" >Saquon Barkley</td>
#       <td id="T_774b7_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_774b7_row1_col2" class="data row1 col2" >5.000000</td>
#       <td id="T_774b7_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_774b7_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_774b7_row1_col5" class="data row1 col5" >3.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row2_col0" class="data row2 col0" >Jahmyr Gibbs</td>
#       <td id="T_774b7_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_774b7_row2_col2" class="data row2 col2" >8.000000</td>
#       <td id="T_774b7_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_774b7_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_774b7_row2_col5" class="data row2 col5" >5.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row3_col0" class="data row3 col0" >Bijan Robinson</td>
#       <td id="T_774b7_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_774b7_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_774b7_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_774b7_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_774b7_row3_col5" class="data row3 col5" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row4_col0" class="data row4 col0" >Josh Jacobs</td>
#       <td id="T_774b7_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_774b7_row4_col2" class="data row4 col2" >12.000000</td>
#       <td id="T_774b7_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_774b7_row4_col4" class="data row4 col4" >4.000000</td>
#       <td id="T_774b7_row4_col5" class="data row4 col5" >7.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row5_col0" class="data row5 col0" >Kyren Williams</td>
#       <td id="T_774b7_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_774b7_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_774b7_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_774b7_row5_col4" class="data row5 col4" >6.000000</td>
#       <td id="T_774b7_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row6_col0" class="data row6 col0" >James Cook</td>
#       <td id="T_774b7_row6_col1" class="data row6 col1" >22</td>
#       <td id="T_774b7_row6_col2" class="data row6 col2" >14.000000</td>
#       <td id="T_774b7_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_774b7_row6_col4" class="data row6 col4" >15.000000</td>
#       <td id="T_774b7_row6_col5" class="data row6 col5" >7.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row7_col0" class="data row7 col0" >Jonathan Taylor</td>
#       <td id="T_774b7_row7_col1" class="data row7 col1" >24</td>
#       <td id="T_774b7_row7_col2" class="data row7 col2" >4.000000</td>
#       <td id="T_774b7_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_774b7_row7_col4" class="data row7 col4" >16.000000</td>
#       <td id="T_774b7_row7_col5" class="data row7 col5" >4.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row8_col0" class="data row8 col0" >De'Von Achane</td>
#       <td id="T_774b7_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_774b7_row8_col2" class="data row8 col2" >17.000000</td>
#       <td id="T_774b7_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_774b7_row8_col4" class="data row8 col4" >1.000000</td>
#       <td id="T_774b7_row8_col5" class="data row8 col5" >8.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row9_col0" class="data row9 col0" >Joe Mixon</td>
#       <td id="T_774b7_row9_col1" class="data row9 col1" >6</td>
#       <td id="T_774b7_row9_col2" class="data row9 col2" >15.000000</td>
#       <td id="T_774b7_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_774b7_row9_col4" class="data row9 col4" >4.000000</td>
#       <td id="T_774b7_row9_col5" class="data row9 col5" >5.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row10_col0" class="data row10 col0" >James Conner</td>
#       <td id="T_774b7_row10_col1" class="data row10 col1" >20</td>
#       <td id="T_774b7_row10_col2" class="data row10 col2" >19.000000</td>
#       <td id="T_774b7_row10_col3" class="data row10 col3" >11</td>
#       <td id="T_774b7_row10_col4" class="data row10 col4" >9.000000</td>
#       <td id="T_774b7_row10_col5" class="data row10 col5" >8.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row11_col0" class="data row11 col0" >Chase Brown</td>
#       <td id="T_774b7_row11_col1" class="data row11 col1" >63</td>
#       <td id="T_774b7_row11_col2" class="data row11 col2" >33.000000</td>
#       <td id="T_774b7_row11_col3" class="data row11 col3" >12</td>
#       <td id="T_774b7_row11_col4" class="data row11 col4" >51.000000</td>
#       <td id="T_774b7_row11_col5" class="data row11 col5" >21.000000</td>
#     </tr>
#     <tr>
#       <td id="T_774b7_row12_col0" class="data row12 col0" >Alvin Kamara</td>
#       <td id="T_774b7_row12_col1" class="data row12 col1" >23</td>
#       <td id="T_774b7_row12_col2" class="data row12 col2" >16.000000</td>
#       <td id="T_774b7_row12_col3" class="data row12 col3" >13</td>
#       <td id="T_774b7_row12_col4" class="data row12 co

# %% [markdown]
# ## 2025 Non-Rookie Running Back Ranking Predictions

# %%
top20_2025 = predict_future_year(starters_model, 2025, features, top_n=20)
top20_2025
# Out:
# <style type="text/css">
# </style>
# <table id="T_78e56">
#   <thead>
#     <tr>
#       <th id="T_78e56_level0_col0" class="col_heading level0 col0" >Player</th>
#       <th id="T_78e56_level0_col1" class="col_heading level0 col1" >Predicted Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_78e56_row0_col0" class="data row0 col0" >Christian McCaffrey</td>
#       <td id="T_78e56_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row1_col0" class="data row1 col0" >Jahmyr Gibbs</td>
#       <td id="T_78e56_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row2_col0" class="data row2 col0" >Bijan Robinson</td>
#       <td id="T_78e56_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row3_col0" class="data row3 col0" >Derrick Henry</td>
#       <td id="T_78e56_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row4_col0" class="data row4 col0" >Travis Etienne</td>
#       <td id="T_78e56_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row5_col0" class="data row5 col0" >Joe Mixon</td>
#       <td id="T_78e56_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row6_col0" class="data row6 col0" >Saquon Barkley</td>
#       <td id="T_78e56_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row7_col0" class="data row7 col0" >Breece Hall</td>
#       <td id="T_78e56_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row8_col0" class="data row8 col0" >Josh Jacobs</td>
#       <td id="T_78e56_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row9_col0" class="data row9 col0" >De'Von Achane</td>
#       <td id="T_78e56_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row10_col0" class="data row10 col0" >Tony Pollard</td>
#       <td id="T_78e56_row10_col1" class="data row10 col1" >11</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row11_col0" class="data row11 col0" >Raheem Mostert</td>
#       <td id="T_78e56_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row12_col0" class="data row12 col0" >Kyren Williams</td>
#       <td id="T_78e56_row12_col1" class="data row12 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row13_col0" class="data row13 col0" >Kenneth Walker III</td>
#       <td id="T_78e56_row13_col1" class="data row13 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row14_col0" class="data row14 col0" >Rachaad White</td>
#       <td id="T_78e56_row14_col1" class="data row14 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row15_col0" class="data row15 col0" >David Montgomery</td>
#       <td id="T_78e56_row15_col1" class="data row15 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row16_col0" class="data row16 col0" >Najee Harris</td>
#       <td id="T_78e56_row16_col1" class="data row16 col1" >17</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row17_col0" class="data row17 col0" >D'Andre Swift</td>
#       <td id="T_78e56_row17_col1" class="data row17 col1" >18</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row18_col0" class="data row18 col0" >Austin Ekeler</td>
#       <td id="T_78e56_row18_col1" class="data row18 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_78e56_row19_col0" class="data row19 col0" >James Conner</td>
#       <td id="T_78e56_row19_col1" class="data row19 col1" >20</td>
#     </tr>
#   </tbody>
# </table>
